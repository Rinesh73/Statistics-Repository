# %% [markdown]
# --------------------------------

# %%
# Calling libraries
import numpy             as np
import pandas            as pd
import scipy.stats       as stats
import matplotlib.pyplot as plt
import seaborn           as sns
from PIL import Image

# %% [markdown]
# #  <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> ------------ INTRODUCTION TO STATISTICS ---------------

# %%
img1 = Image.open("1.png") 
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=842x445 at 0x247B24A4A58>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">Descriptive statistics

# %%
img2 = Image.open("2.png") 
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=831x429 at 0x247B24A5358>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Inferential statistics

# %%
img3 = Image.open("3.png") 
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=839x456 at 0x247B24A5080>

# %% [markdown]
#  ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Population and Sample

# %%
img4 = Image.open("4.png") 
img4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=839x460 at 0x247B24A5630>

# %% [markdown]
#  ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Types of Data Analysis

# %%
img5 = Image.open("5.png") 
img5
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=367x185 at 0x247B24A5DA0>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">  EDA :-

# %%
img6 = Image.open("6.png") 
img6
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=842x458 at 0x247B24B00B8>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">   DATA

# %%
img7 = Image.open("7.png") 
img7
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=841x459 at 0x257B0272128>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Examples for data types

# %%
img8 = Image.open("8.png") 
img8
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=881x483 at 0x257B029EDD8>

# %%
img9 = Image.open("9.png") 
img9
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=882x480 at 0x257B0299208>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Variable

# %%
img10 = Image.open("10.png") 
img10
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=881x480 at 0x257B0299DA0>

# %%
img11 = Image.open("11.png") 
img11
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=869x474 at 0x257B02AE320>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Different file formats and how to read them in Python.

# %% [markdown]
# ## Setup your workdirectory in your local machine.

# %%
import os
os.chdir('C:\\Users\\Public\\Downloads')

# %% [markdown]
# ### (a). Data in 'csv' Format.

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# ### (b). Data in 'xlsx' Format.

# %%
df = pd.read_excel("data.xlsx", sheetname ="abc")

# %% [markdown]
# ### (c). Data in 'zip' file.

# %%
import zipfile
archive = zipfile.ZipFile('T.zip', 'r')
df = archive.read('data.csv')

# %% [markdown]
# ### (d). Data in 'text' Format.

# %%
text_file = open("text.txt", "r")
lines = text_file.read()

# %% [markdown]
# ### (e). Data in 'json' Format.

# %%
df = pd.read_json("data.json")

# %% [markdown]
# ### (f). Data in 'xml' Format.

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('data.xml')
root = tree.getroot()
print root.tag

# %% [markdown]
# ### (g). Data in 'pdf' Format.

# %%
pdf2txt.py <pdf_file>.pdf

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Descriptive data measures

# %%
img12 = Image.open("12.png") 
img12
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=865x462 at 0x257B025EF28>

# %% [markdown]
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">Measure of Central Tendency

# %% [markdown]
# ## (a). Mean:

# %%
img13 = Image.open("13.png") 
img13
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=939x521 at 0x257B0358CF8>

# %%
Data1  = [3,5,2,8,9,2,7,2,2,2]

# %%
np.mean(Data1)
# Out:
# 4.2

# %% [markdown]
# ## (b). Median:

# %%
img14 = Image.open("14.png") 
img14
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=940x521 at 0x257B01CC128>

# %%
Data1  = [3,5,2,8,9,2,7,2,2,2]

# %%
np.median(Data1)
# Out:
# 2.5

# %% [markdown]
# ## (c). Mode:

# %%
img15 = Image.open("15.png") 
img15
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x472 at 0x257B3881EF0>

# %%
Data1  = [3,5,2,8,9,2,7,2,2,2]

# %%
import statistics 
statistics.mode(Data1)
# Out:
# 2

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Measure of dispersion

# %%
img16 = Image.open("16.png") 
img16
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=870x489 at 0x257B045CF28>

# %%
img17 = Image.open("17.png") 
img17
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=863x477 at 0x257B045C5F8>

# %% [markdown]
# ## (a). Range:

# %%
img18 = Image.open("18.png") 
img18
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=861x475 at 0x257B045C7B8>

# %%
Data1  = [3,5,2,8,9,2,7,2,2,2]

# %%
max(Data1)-min(Data1)
# Out:
# 7

# %% [markdown]
# ## (b). Quartile:

# %%
img19 = Image.open("19.png") 
img19
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=861x478 at 0x257B0468358>

# %%
img20 = Image.open("20.png") 
img20
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x478 at 0x257B0464F28>

# %%
Data1  = [3,5,2,8,9,2,7,2,2,2]

# %%
np.quantile(Data1,q=0.25) # 25th Percentile
# Out:
# 2.0

# %%
np.quantile(Data1,q=0.50) # 50th Percentile
# Out:
# 2.5

# %%
np.quantile(Data1,q=0.75) # 75th Percentile
# Out:
# 6.5

# %% [markdown]
# ## (c). IQR - (Inter Quartile Range )

# %%
img21 = Image.open("21.png") 
img21
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=869x485 at 0x257B4869390>

# %%
Q1=np.quantile(Data1,q=0.25) # 25th Percentile

Q3=np.quantile(Data1,q=0.75) # 75th Percentile

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 4.5

# %% [markdown]
# ## (d). Standard Deviation :

# %%
img22 = Image.open("22.png") 
img22
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=869x487 at 0x257B49FA710>

# %%
Data1  = [3,5,2,8,9,2,7,2,2,2]

# %%
np.std(Data1)
# Out:
# 2.6758176320519307

# %% [markdown]
# ## Co-efficient of Variation

# %%
img23 = Image.open("23.png") 
img23
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=873x485 at 0x257B4CEF278>

# %% [markdown]
# ## Example for Co-efficient of variation

# %%
img24 = Image.open("24.png") 
img24
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=866x479 at 0x257B4CBC8D0>

# %% [markdown]
# ## Z-Score

# %%
img25 = Image.open("25.png") 
img25
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=864x479 at 0x257B4869A58>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">  Five Number Summary

# %%
img26 = Image.open("26.png") 
img26
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=747x327 at 0x257B492E710>

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Shape of data

# %% [markdown]
# ## (a). Skewness

# %%
img27 = Image.open("27.png") 
img27
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=863x485 at 0x257B50B9DD8>

# %% [markdown]
# ## (b). Kurtosis

# %%
img28 = Image.open("28.png") 
img28
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=871x483 at 0x257B3706B70>

# %% [markdown]
# ### <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> -- Relationships among Five number summary and distribution of shape --

# %%
img29 = Image.open("29.png") 
img29
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=860x476 at 0x257B4921BA8>

# %% [markdown]
# ### <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> -- Box-Plot Display of Data on Five Number Summary --

# %%
img30 = Image.open("30.png") 
img30
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=863x483 at 0x257B4A3A518>

# %% [markdown]
# ### <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Distribution of shape and Box-Plot

# %%
img31 = Image.open("31.png") 
img31
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x480 at 0x257B492E550>

# %% [markdown]
# ### <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> Box-Plot  Displaying  of Outlier

# %%
img32 = Image.open("32.png") 
img32
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=863x485 at 0x257B49CDB70>

# %% [markdown]
# ### <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">Co-variance and Co-efficient of co-relation

# %%
img33 = Image.open("33.png") 
img33
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x478 at 0x257B4CBB630>

# %% [markdown]
# ## Scatter Plot - for displaying of different types of co-relation

# %%
img34 = Image.open("34.png") 
img34
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=861x474 at 0x257BFD6E518>

# %%
img35 = Image.open("35.png") 
img35
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x481 at 0x257B5986DD8>

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> CASE STUDY

# %% [markdown]
# This dataset is created for prediction of Graduate Admissions from an Indian perspective.
#
#     1. GRE Scores ( 290 of 340 )
#     2. TOEFL Scores ( 92 of 120 )
#     3. University Rating ( 1 of 5 )
#     4. Statement of Purpose ( 1 of 5 )
#     5. Letter of Recommendation Strength ( 1 of 5 )
#     6. Undergraduate GPA ( 6.8 of 10 )
#     7. Research Experience ( 0 or 1 )
#     8. Chance of Admit ( ranging from  0.34 to 0.97)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">  Data Understanding

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.1 Load the libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.2. Import the dataset(Graduate Admissions.csv):

# %%
Data  = pd.read_csv('Admission_Predict.csv')
Data .head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.3 Check the Dimension of data?

# %%
Data.shape
# Out:
# (400, 9)

# %% [markdown]
# **There is 400 Observations / Rows and 9 Attributes / Columns.**

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.4 Check the Information about the data and the datatypes of each respective attributes.

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
# Serial No.           400 non-null int64
# GRE Score            400 non-null int64
# TOEFL Score          400 non-null int64
# University Rating    400 non-null int64
# SOP                  400 non-null float64
# LOR                  400 non-null float64
# CGPA                 400 non-null float64
# Research             400 non-null int64
# Chance of Admit      400 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.7em;color:#00b3e5;">EDA Descriptive Statistics

# %% [markdown]
# ### Mean

# %%
print("Data:",Data.mean())
# Out:
# Data: Serial No.           200.500000
# GRE Score            316.807500
# TOEFL Score          107.410000
# University Rating      3.087500
# SOP                    3.400000
# LOR                    3.452500
# CGPA                   8.598925
# Research               0.547500
# Chance of Admit        0.724350
# dtype: float64

# %%
# the Above code will provide the average/mean values for all individual attributes.
# the average highest Marks scored in 'GRE EXAM'.

# %% [markdown]
# ### Mode

# %%
print("Data[GRE Score]:",Data['GRE Score'].mode())
# Out:
# Data[GRE Score]: 0    312
# 1    324
# dtype: int64

# %%
# we can observe from our descriptive analysis that in GRE Scores (312,324) are most oftenly scored marks by many students.

# %% [markdown]
# ### Median

# %%
print("Data:",Data.median())
# Out:
# Data: Serial No.           200.50
# GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.61
# Research               1.00
# Chance of Admit        0.73
# dtype: float64

# %%
# we can observe that the Middle/Median value from the above output that our mean and median values are closly same hence we can say that they is no skewness in the data

# %% [markdown]
# ### Quantile 25%

# %%
print("Data_quantile(25%):",Data.quantile(q=0.25))
# Out:
# Data_quantile(25%): GRE Score            308.00
# TOEFL Score          103.00
# University Rating      2.00
# SOP                    2.50
# LOR                    3.00
# CGPA                   8.17
# Research               0.00
# Chance of Admit        0.64
# Name: 0.25, dtype: float64

# %%
# the above output brief's about the data regarding the 25th percentile / 1st Quartile.

# %% [markdown]
# ### Quantile 50%

# %%
print("Data_quantile(50%):",Data.quantile(q=0.50))
# Out:
# Data_quantile(25%): Serial No.           200.50
# GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.61
# Research               1.00
# Chance of Admit        0.73
# Name: 0.5, dtype: float64

# %%
# the above output brief's about the data regarding the 50 th percentile / 2nd Quartile.

# %% [markdown]
# ### Quantile 75%

# %%
print("Data_quantile(75%):",Data.quantile(q=0.75))
# Out:
# Data_quantile(75%): Serial No.           300.2500
# GRE Score            325.0000
# TOEFL Score          112.0000
# University Rating      4.0000
# SOP                    4.0000
# LOR                    4.0000
# CGPA                   9.0625
# Research               1.0000
# Chance of Admit        0.8300
# Name: 0.75, dtype: float64

# %%
# the above output brief's about the data regarding the 75th percentile / 3rd Quartile.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.5a) Plotting the summery mean,mode,median using histogram

# %%
saleprice = Data['GRE Score']

mean=Data['GRE Score'].mean()
median=Data['GRE Score'].median()
mode=Data['GRE Score'].mode()

print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])
plt.figure(figsize=(10,5))
plt.hist(Data['GRE Score'],bins=100,color='#e6f49f')
plt.axvline(mean,color='#ed0909',label='Mean')
plt.axvline(median,color='#2a22c9',label='Median')
plt.axvline(mode[0],color='green',label='Mode')
plt.xlabel('GRE Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Mean:  316.8075
# Median:  317.0
# Mode:  312

# %%
# from the above output graph we can observe that the data doesn't tend to have skewness and closely normally distributed.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.6 Check the data.describe()

# %%
Data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
# the above output results provide the five number summary of the data.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> IQR Value for TOEFL Score

# %%
Data["TOEFL Score"].quantile(0.75) - Data["TOEFL Score"].quantile(0.25)
# Out:
# 9.0

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.6a)Undestanding the summary of Statistics plotting  Box plots

# %%
# Create boxplot for column="mpg"
Data.boxplot(column="TOEFL Score",return_type='axes',figsize=(8,8))

# create text(x=0.74, y=22.25, s="3rd Quartile")like Median, 1st Quartile,Min,Max,IQR:
plt.text(x=0.74, y=112.00, s="3rd Quartile")
plt.text(x=0.8, y=107.00, s="Median")
plt.text(x=0.75, y=103.00, s="1st Quartile")
plt.text(x=0.9, y=92.00, s="Min")
plt.text(x=0.9, y=120.00, s="Max")
plt.text(x=0.7, y=107.5, s="IQR", rotation=90, size=25)
# Out:
# Text(0.7, 107.5, 'IQR')

# %%
# we can observe from above graph that there are no extreme values / outliers.the data was equally distributed .

# %% [markdown]
#  <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.7 Check the Measures of Dispersion:

# %% [markdown]
# ### IQR

# %%
Data.quantile(0.75) - Data.quantile(0.25)
# Out:
# Serial No.           199.5000
# GRE Score             17.0000
# TOEFL Score            9.0000
# University Rating      2.0000
# SOP                    1.5000
# LOR                    1.0000
# CGPA                   0.8925
# Research               1.0000
# Chance of Admit        0.1900
# dtype: float64

# %%
# the above output represents the IQR values for all the attributed.

# %% [markdown]
# ### Range

# %%
print(Data.max() - Data.min())
# Out:
# Serial No.           399.00
# GRE Score             50.00
# TOEFL Score           28.00
# University Rating      4.00
# SOP                    4.00
# LOR                    4.00
# CGPA                   3.12
# Research               1.00
# Chance of Admit        0.63
# dtype: float64

# %%
# the above represents the difference between the highest value and lowest values for all individual attributes.

# %% [markdown]
# ### Variance

# %%
print(Data.var())
# Out:
# Serial No.           13366.666667
# GRE Score              131.644555
# TOEFL Score             36.838997
# University Rating        1.308114
# SOP                      1.013784
# LOR                      0.807262
# CGPA                     0.355594
# Research                 0.248365
# Chance of Admit          0.020337
# dtype: float64

# %%
# the above output brief's regarding how much was the data dispersion .

# %% [markdown]
# ### Standard Deviation

# %%
print(Data.std())
# Out:
# Serial No.           115.614301
# GRE Score             11.473646
# TOEFL Score            6.069514
# University Rating      1.143728
# SOP                    1.006869
# LOR                    0.898478
# CGPA                   0.596317
# Research               0.498362
# Chance of Admit        0.142609
# dtype: float64

# %%
# the above output brief's regarding how much was the data deviated away from the mean .

# %% [markdown]
# ### Absolute Deviation or Mean Absolute Deviation

# %%
print(Data.mad())
# Out:
# Serial No.           100.000000
# GRE Score              9.492313
# TOEFL Score            4.988450
# University Rating      0.911375
# SOP                    0.832500
# LOR                    0.734625
# CGPA                   0.487236
# Research               0.495487
# Chance of Admit        0.114363
# dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;">1.8 Check Covariance and Correlation

# %% [markdown]
# ### Covariance

# %%
print(Data.cov())
# Out:
#                      Serial No.   GRE Score  TOEFL Score  University Rating  \
# Serial No.         13366.666667 -129.369674  -103.807018         -22.472431
# GRE Score           -129.369674  131.644555    58.216967           8.778791
# TOEFL Score         -103.807018   58.216967    36.838997           4.828697
# University Rating    -22.472431    8.778791     4.828697           1.308114
# SOP                  -19.432331    7.079699     4.021053           0.845865
# LOR                   -9.164160    5.747726     3.095965           0.678352
# CGPA                  -3.144373    5.699742     2.998337           0.509117
# Research              -3.637845    3.318690     1.481729           0.255232
# Chance of Admit        0.698020    1.313271     0.685179           0.116009
#
#                          SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -19.432331 -9.164160 -3.144373 -3.637845          0.698020
# ...

# %% [markdown]
# ### Correlation

# %%
print(Data.corr())
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.8a) Pairplot for checking the correlation?

# %%
# library & dataset
import matplotlib.pyplot as plt
import seaborn as sns

 
# with regression
sns.pairplot(Data, kind="reg")
plt.show()

# %% [markdown]
# 1. Here we can see TOEFL Score positively correlated all variable except Serial No. Lets look Heatmap and see the correlation rage(1, 0, -1)

# %%
Data.drop('Serial No.', axis=1, inplace=True)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.8b) Heatmap For checking the correlation?

# %%
fig,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(Data.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %%
# we can confirm that TOEFL Score has highest postive co-relation with all the attributes.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.9 Check the Skewness and Kurtosis

# %% [markdown]
# **Positively skewed:** Most frequent values are low and tail is towards high values.
#
# **Negatively skewed:** Most frequent values are high and tail is towards low values.

# %% [markdown]
# If **Mode< Median< Mean** then the distribution is positively skewed.
#
# If **Mode> Median> Mean** then the distribution is negatively skewed.

# %%
Data.skew()
# Out:
# Serial No.           0.000000
# GRE Score           -0.062893
# TOEFL Score          0.057216
# University Rating    0.171260
# SOP                 -0.275761
# LOR                 -0.106991
# CGPA                -0.065991
# Research            -0.191582
# Chance of Admit     -0.353448
# dtype: float64

# %%
Data.kurt()
# Out:
# Serial No.          -1.200000
# GRE Score           -0.700489
# TOEFL Score         -0.578778
# University Rating   -0.796287
# SOP                 -0.675610
# LOR                 -0.662484
# CGPA                -0.458476
# Research            -1.973187
# Chance of Admit     -0.389126
# dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#00b3e5;"> 1.10 Histogram for checking the Skewness and Kurtosis

# %%
import scipy.stats as stats

#convert pandas DataFrame object to numpy array and sort
h = np.asarray(Data['GRE Score'])
h = sorted(h)
 
#use the scipy stats module to fit a normal distirbution with same mean and standard deviation
fit = stats.norm.pdf(h, np.mean(h), np.std(h)) 
 
#plot both series on the histogram
plt.plot(h,fit,'-',linewidth = 2,label="Normal distribution with same mean and var")
plt.hist(h,normed=True,bins = 100,label="Actual distribution")      
plt.legend()
plt.show()

# %% [markdown]
# * We can see int the above graph that it is negative skewed with skewness score -0.06 and also has Negative kurtosis(k=-0.70)

# %% [markdown]
# -------------------------------

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#f97102;"> ---------------------------- HAPPY LEARNING -----------------------------------

# %% [markdown]
# ----------------------------------------
